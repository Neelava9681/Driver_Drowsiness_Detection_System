# %%
# !pip install tensorflow
# Out:
# ...
#   Using cached libclang-16.0.6-py2.py3-none-win_amd64.whl.metadata (5.3 kB)
# ...
#      ---------------------------------------- 0.0/895.7 kB ? eta -:--:--
#      - ----------------------------------- 41.0/895.7 kB 991.0 kB/s eta 0:00:01
#      ------ ------------------------------- 143.4/895.7 kB 1.7 MB/s eta 0:00:01
#      --------------- ---------------------- 358.4/895.7 kB 2.8 MB/s eta 0:00:01
#      --------------------- ---------------- 501.8/895.7 kB 3.2 MB/s eta 0:00:01
#      ------------------------------------ - 860.2/895.7 kB 3.6 MB/s eta 0:00:01
#      -------------------------------------- 895.7/895.7 kB 3.8 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 0.0/1.5 MB ? eta -:--:--
#      -- ------------------------------------- 0.1/1.5 MB ? eta -:--:--
#      --------------- ------------------------ 0.6/1.5 MB 9.4 MB/s eta 0:00:01
#      ------------------ --------------------- 0.7/1.5 MB 5.5 MB/s eta 0:00:01
# ...

# %%
import tensorflow as tf
import keras
from tensorflow.keras.applications import InceptionV3
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dropout,Input,Flatten,Dense,MaxPooling2D
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from keras.models import Sequential
from keras.optimizers import Adam
from keras.losses import categorical_crossentropy
# !pip install scipy
import scipy

# %%
from PIL import Image

# %%
tf.test.is_gpu_available()
# Out:
# WARNING:tensorflow:From C:\Users\Neelava\AppData\Local\Temp\ipykernel_2120\337460670.py:1: is_gpu_available (from tensorflow.python.framework.test_util) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.config.list_physical_devices('GPU')` instead.
# False

# %%
train_datagen=ImageDataGenerator(rescale=1./255,
                                 rotation_range=0.2,
                                 shear_range=0.2,
                                 zoom_range=0.2,
                                 width_shift_range=0.2,
                                 height_shift_range=0.2,
                                 validation_split=0.2
                                )

# %%
batchsize=8

# %%
train_data = train_datagen.flow_from_directory(
    r'C:\Users\Neelava\driver_drowsiness_detection\Prepared_Data\Train',
    target_size=(80, 80),
    batch_size=batchsize,
    class_mode='categorical',
    subset='training'
)

validation_data= train_datagen.flow_from_directory(
    r'C:\Users\Neelava\driver_drowsiness_detection\Prepared_Data\Train',
    target_size=(80, 80),
    batch_size=batchsize,
    class_mode='categorical',
    subset='validation'
    
)
# Out:
# Found 26214 images belonging to 2 classes.
# Found 6552 images belonging to 2 classes.

# %%
test_datagen=ImageDataGenerator(rescale=1./255,)
test_data=test_datagen.flow_from_directory(
    r'C:\Users\Neelava\driver_drowsiness_detection\Prepared_Data\Test',
    target_size=(80, 80),
    batch_size=batchsize,
    class_mode='categorical'
)
# Out:
# Found 8512 images belonging to 2 classes.

# %%
base_model=InceptionV3(include_top=False,weights='imagenet',input_tensor=Input(shape=(80,80,3)))
head_model=base_model.output
head_model=Flatten()(head_model)
head_model=Dense(64,activation='relu')(head_model)
head_model=Dropout(0.5)(head_model)
head_model=Dense(2,activation='softmax')(head_model)
model=Model(inputs=base_model.input,outputs=head_model)
for layer in base_model.layers:
    layer.trainable=False

# %%
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ...
#  input_1 (InputLayer)           [(None, 80, 80, 3)]  0           []
#
#  conv2d (Conv2D)                (None, 39, 39, 32)   864         ['input_1[0][0]']
#
#  batch_normalization (BatchNorm  (None, 39, 39, 32)  96          ['conv2d[0][0]']
#  alization)
#
#  activation (Activation)        (None, 39, 39, 32)   0           ['batch_normalization[0][0]']
#
#  conv2d_1 (Conv2D)              (None, 37, 37, 32)   9216        ['activation[0][0]']
#
#  batch_normalization_1 (BatchNo  (None, 37, 37, 32)  96          ['conv2d_1[0][0]']
#  rmalization)
#
#  activation_1 (Activation)      (None, 37, 37, 32)   0           ['batch_normalization_1[0][0]']
#
#  conv2d_2 (Conv2D)              (None, 37, 37, 64)   18432       ['activation_1[0][0]']
#
# ...

# %%
from tensorflow.keras.callbacks import ModelCheckpoint,EarlyStopping,ReduceLROnPlateau

# %%
checkpoint=ModelCheckpoint(r"C:\Users\Neelava\driver_drowsiness_detection\models\model.h5",
                          monitor='val_loss',
                           save_best_only=True,
                           verbose=3
                          )
earlystop=EarlyStopping(monitor='val_loss',patience=10,verbose=3,restore_best_weights=True)
learning_rate= ReduceLROnPlateau(monitor='val_loss',patience=5,verbose=3)
callbacks=[checkpoint,earlystop,learning_rate]

# %%
# model.compile(optimizer='Adam',loss='categorical_crossentropy',metrics=['accuracy'])

# %%
model.compile(optimizer='Adam',loss='categorical_crossentropy',metrics=['accuracy'])

model.fit_generator(train_data,steps_per_epoch=train_data.samples//batchsize,
                   validation_data=validation_data,
                   validation_steps=validation_data.samples//batchsize,
                   callbacks=callbacks,
                   epochs=50)
# Out:
# C:\Users\Neelava\AppData\Local\Temp\ipykernel_2120\1269288209.py:3: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   model.fit_generator(train_data,steps_per_epoch=train_data.samples//batchsize,
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[26], line 3
#       1 model.compile(optimizer='Adam',loss='categorical_crossentropy',metrics=['accuracy'])
# ----> 3 model.fit_generator(train_data,steps_per_epoch=train_data.samples//batchsize,
#       4                    validation_data=validation_data,
#       5                    validation_steps=validation_data.samples//batchsize,
#       6                    callbacks=callbacks,
#       7                    epochs=50)
#
# ...

# %%
from PIL import Image
model=Sequential()
# !pip install scipy

# %% [markdown]
# # Model evaluation

# %%
accuracy_training,loss_training=model.evaluate_generator(train_data)
print(accuracy_training)
print(loss_training)
# Out:
# C:\Users\Neelava\AppData\Local\Temp\ipykernel_2120\68675993.py:1: UserWarning: `Model.evaluate_generator` is deprecated and will be removed in a future version. Please use `Model.evaluate`, which supports generators.
#   accuracy_training,loss_training=model.evaluate_generator(train_data)
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[28], line 1
# ----> 1 accuracy_training,loss_training=model.evaluate_generator(train_data)
#       2 print(accuracy_training)
#       3 print(loss_training)
#
# File ~\anaconda3\envs\tensorflow\lib\site-packages\keras\engine\training.py:2549, in Model.evaluate_generator(self, generator, steps, callbacks, max_queue_size, workers, use_multiprocessing, verbose)
#    2541 warnings.warn(
#    2542     "`Model.evaluate_generator` is deprecated and "
#    2543     "will be removed in a future version. "
# ...

# %%
accuracy_validation,loss_validation=model.evaluate_generator(validation_data)
print(accuracy_validation)
print(loss_validation)

# %%
accuracy_test,loss_test=model.evaluate_generator(test_data)
print(accuracy_test)
print(loss_test)
